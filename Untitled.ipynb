# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Set Option
pd.set_option('max_colwidth', 10000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df_1 = pd.read_csv('Data/1.csv')
df_2 = pd.read_csv('Data/2.csv')
frames = [df_1,df_2]
items_df = pd.concat(frames, ignore_index=True, sort=False)
for i in range(3,63,2):
    df_1 = pd.read_csv(f'Data/{i}.csv')
    df_2 = pd.read_csv(f'Data/{i+1}.csv')
    frames = [items_df,df_1,df_2]
#     items_df = pd.concat(frames, keys = [f'{i}',f'{i+1}''])
    items_df = pd.concat(frames, ignore_index=True, sort=False)

df_1 = pd.read_csv('Data/63.csv')
frames = [items_df,df_1]
items_df = pd.concat(frames, ignore_index=True, sort=False)
# Sử dụng lệnh dưới thay vì lệnh đang dùng ở phía trên, các dataframe được gộp với nhau 
# nhưng vẫn có thể gọi riêng một dataframe thông qua key.
# Tuy nhiên chỉ số index sẽ không chạy từ 0 đến hết mà giữ nguyên ở mỗi bảng.

# items_df = pd.concat(frames, keys = [aoNganTayKhongCo', 'aoSoMi', 'baloTuiVi', 'giayDepNam', 'phuKienNam', 'Quan'])

# %%
items_df['SBD'].loc[1063438]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 1063438 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-5f13cabf38a8> in <module>
# ----> 1 items_df['SBD'].loc[1063438]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
# ...

# %%
df_HaGiang = pd.read_csv('Data/4.csv')
df_HaGiang
# Out:
#           SBD  TOÁN   VĂN    LÝ   HÓA  SINH    SỬ   ĐỊA  GDCD  ANH  KHTN  KHXH  KHỐI A  KHỐI B  KHỐI C  KHỐI D  KHỐI A1
# 0     5002915   1.4  2.00   NaN   NaN   NaN  2.25  5.25  4.25  3.4   NaN  3.92     NaN     NaN    9.50    6.80      NaN
# 1     5000921   5.6  4.75  6.50  3.75  3.50  2.75  6.75  7.75  2.4  4.58  5.75   15.85   12.85   14.25   12.75    14.50
# 2     5000863   3.8  3.50  2.75  2.75  2.75  2.50  3.75  5.25  4.0  2.75  3.83    9.30    9.30    9.75   11.30    10.55
# 3     5000867   2.4  2.75  2.00  3.50  3.25  4.25  5.00  6.75  3.0  2.92  5.33    7.90    9.15   12.00    8.15     7.40
# 4     5000909   9.4  3.25  9.00  3.25  3.00   NaN   NaN   NaN  9.6  5.08   NaN   21.65   15.65     NaN   22.25    28.00
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...   ...     ...     ...     ...     ...      ...
# 3094  5003209   2.6  4.00   NaN   NaN   NaN  4.25  4.50  6.25  2.6   NaN  5.00     NaN     NaN   12.75    9.20      NaN
# ...
